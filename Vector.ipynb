# %%
import PIL.Image as pilimg
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
filename="image/vector.jpg"
a = pilimg.open(filename)

# %%
a
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=828x713 at 0x277EF193FD0>

# %%
v1 = np.array([1,5,9])
v2 = np.array([3,7,11])

# %%
v3 = v1 + v2 # sum of vector
v4 = 3*v1 #scalr product of vector
print(v3, v4)
# Out:
# [ 4 12 20] [ 3 15 27]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot([0,0,0],v4)
plt.show()
